# %% [markdown]
# Install libraries

# %%
# !pip install deep_translator
# !pip install textblob
# !pip install langdetect
# !pip install vaderSentiment
# Out:
# Collecting deep_translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from deep_translator) (4.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from deep_translator) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep_translator) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (2024.8.30)
# Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: deep_translator
# Successfully installed deep_translator-1.11.4
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (4.66.6)
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 23.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect) (1.16.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993222 sha256=c37c9703a04fe1baf144b2f55481582207035deefd23a852c29f9a70cc428037
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl.metadata (572 bytes)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vaderSentiment) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2024.8.30)
# Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %% [markdown]
# Import libraries

# %%
import pandas as pd
from deep_translator import GoogleTranslator
from textblob import TextBlob

# %% [markdown]
# Import data

# %%
csv_file = '/content/filtered_reviews.csv'

# Set up an empty list to hold the filtered DataFrame chunks
filtered_chunks = []

# Read the CSV file in chunks and filter rows where 'date' >= '2023-12-01'
# Only keep relevant fields: date, listing_id, reviewer_id, comments
for chunk in pd.read_csv(csv_file, chunksize=1000, parse_dates=['date'], usecols=['date', 'listing_id', 'reviewer_id', 'comments']):
    filtered_chunk = chunk[chunk['date'] >= '2023-12-01']
    filtered_chunks.append(filtered_chunk)

# Combine the filtered chunks into a single DataFrame
reviews_df = pd.concat(filtered_chunks, ignore_index=True)

# %%
reviews_df
# Out:
#                 listing_id       date  reviewer_id  \
# 0                  1992333 2023-12-01     37012494
# 1                  1992333 2023-12-09     76872138
# 2                     3191 2023-12-23      9927643
# 3                    15007 2023-12-03    243886263
# 4                   897063 2023-12-01    398675800
# ...                    ...        ...          ...
# 11969  1045539636083237263 2023-12-27      8112629
# 11970  1045595447074880765 2023-12-17    313105614
# 11971  1048683134427485052 2023-12-19     41455737
# 11972  1049033266515220845 2023-12-25     26831109
# 11973  1045601601027572370 2023-12-22      1032934
#
#                                                 comments
# 0      What a place to stay! The view is breathtaking...
# 1      Search no further, this is the place to stay. ...
# 2      This was my second visit and it was as good as...
# 3      Thank you Dirk and your wife for wonderful wee...
# 4          Great place, great location and a great host.
# ...                                                  ...
# 11969  We were extremely comfortable during this visi...
# 11970  The apartment is brand new and definitely felt...
# 11971  I had an amazing stay in this very stylish apa...
# 11972  Anna's Camps Bay Retreat: ⭐⭐⭐⭐⭐<br/>Annas's ap...
# 11973  I will be back! <br/>What a beautiful apartmen...
#
# [11974 rows x 4 columns]

# %% [markdown]
# Clean data

# %%
# Check column types
reviews_df.dtypes
# Out:
# listing_id              int64
# date           datetime64[ns]
# reviewer_id             int64
# comments               object
# dtype: object

# %%
# Standardize data formats
reviews_df.convert_dtypes
# Out:
# <bound method NDFrame.convert_dtypes of                 listing_id       date  reviewer_id  \
# 0                  1992333 2023-12-01     37012494
# 1                  1992333 2023-12-09     76872138
# 2                     3191 2023-12-23      9927643
# 3                    15007 2023-12-03    243886263
# 4                   897063 2023-12-01    398675800
# ...                    ...        ...          ...
# 11969  1045539636083237263 2023-12-27      8112629
# 11970  1045595447074880765 2023-12-17    313105614
# 11971  1048683134427485052 2023-12-19     41455737
# 11972  1049033266515220845 2023-12-25     26831109
# 11973  1045601601027572370 2023-12-22      1032934
#
#                                                 comments
# 0      What a place to stay! The view is breathtaking...
# 1      Search no further, this is the place to stay. ...
# 2      This was my second visit and it was as good as...
# 3      Thank you Dirk and your wife for wonderful wee...
# 4          Great place, great location and a great host.
# ...                                                  ...
# 11969  We were extremely comfortable during this visi...
# 11970  The apartment is brand new and definitely felt...
# 11971  I had an amazing stay in this very stylish apa...
# 11972  Anna's Camps Bay Retreat: ⭐⭐⭐⭐⭐<br/>Annas's ap...
# 11973  I will be back! <br/>What a beautiful apartmen...
#
# [11974 rows x 4 columns]>

# %%
# Check for duplicates
reviews_df.duplicated().sum()
# Out:
# 0

# %%
# Remove duplicates
reviews_df.drop_duplicates()
# Out:
#                 listing_id       date  reviewer_id  \
# 0                  1992333 2023-12-01     37012494
# 1                  1992333 2023-12-09     76872138
# 2                     3191 2023-12-23      9927643
# 3                    15007 2023-12-03    243886263
# 4                   897063 2023-12-01    398675800
# ...                    ...        ...          ...
# 11969  1045539636083237263 2023-12-27      8112629
# 11970  1045595447074880765 2023-12-17    313105614
# 11971  1048683134427485052 2023-12-19     41455737
# 11972  1049033266515220845 2023-12-25     26831109
# 11973  1045601601027572370 2023-12-22      1032934
#
#                                                 comments
# 0      What a place to stay! The view is breathtaking...
# 1      Search no further, this is the place to stay. ...
# 2      This was my second visit and it was as good as...
# 3      Thank you Dirk and your wife for wonderful wee...
# 4          Great place, great location and a great host.
# ...                                                  ...
# 11969  We were extremely comfortable during this visi...
# 11970  The apartment is brand new and definitely felt...
# 11971  I had an amazing stay in this very stylish apa...
# 11972  Anna's Camps Bay Retreat: ⭐⭐⭐⭐⭐<br/>Annas's ap...
# 11973  I will be back! <br/>What a beautiful apartmen...
#
# [11974 rows x 4 columns]

# %%
# Detect and remove non-numerical rows in the 'reviewer_id' column
reviews_df['reviewer_id'] = pd.to_numeric(reviews_df['reviewer_id'], errors='coerce')  # Converts non-numerical values to NaN
reviews_df = reviews_df.dropna(subset=['reviewer_id'])  # Drops rows where 'id_numeric' is NaN

# %% [markdown]
# Transform data

# %%
# Translate non-English comments to English

column_to_translate = 'comments'

from langdetect import detect 

def translate_text(text):
    """
    Translate the given text to English if it's not already in English.

    Parameters:
    - text: str or None, the text to translate.

    Returns:
    - Translated text if input is not None and not in English, else the original text.
    """
    if pd.notnull(text):
        try:
            # Detect the language
            language = detect(text)
            if language != 'en':  # Only translate if the detected language is not English
                return GoogleTranslator(source='auto', target='en').translate(text)
            return text  # Return the original text if it's already in English
        except Exception as e:
            print(f"Error translating text '{text}': {e}")
            return text  # Return the original text if translation fails
    return text  # Return None if input is None

reviews_df['translated_comments'] = reviews_df[column_to_translate].apply(translate_text)
# Out:
# Error translating text '.': No features in text.
# Error translating text '.': No features in text.
# Error translating text '⭐️⭐️⭐️⭐️⭐️': No features in text.
# Error translating text '⭐️⭐️⭐️⭐️⭐️': No features in text.
# Error translating text '10/10': No features in text.
# Error translating text '👌': No features in text.
# Error translating text '-': No features in text.
# Error translating text '👌🏽': No features in text.
# Error translating text '.': No features in text.
# Error translating text '.': No features in text.
# Error translating text '🫶': No features in text.
# Error translating text '.': No features in text.
# Error translating text '👍👍': No features in text.
# Error translating text '👍👍': No features in text.
# Error translating text '10/10': No features in text.
# Error translating text '.': No features in text.
# Error translating text '👍🏼👍🏼👍🏼': No features in text.
# Error translating text '-': No features in text.
# Error translating text '.': No features in text.
# Error translating text '👍': No features in text.
# Error translating text '👌🏼': No features in text.
# Error translating text '12/10': No features in text.
# Error translating text '.': No features in text.
# Error translating text '🦅🦅🦅': No features in text.
# Error translating text '.': No features in text.
# Error translating text '.': No features in text.
# Error translating text '.': No features in text.
# Error translating text '.': No features in text.
# Error translating text ',': No features in text.
# Error translating text '.': No features in text.
# Error translating text '👍🏾': No features in text.
# Error translating text '.': No features in text.

# %%
reviews_df
# Out:
#                 listing_id       date  reviewer_id  \
# 0                  1992333 2023-12-01     37012494
# 1                  1992333 2023-12-09     76872138
# 2                     3191 2023-12-23      9927643
# 3                    15007 2023-12-03    243886263
# 4                   897063 2023-12-01    398675800
# ...                    ...        ...          ...
# 11969  1045539636083237263 2023-12-27      8112629
# 11970  1045595447074880765 2023-12-17    313105614
# 11971  1048683134427485052 2023-12-19     41455737
# 11972  1049033266515220845 2023-12-25     26831109
# 11973  1045601601027572370 2023-12-22      1032934
#
#                                                 comments  \
# 0      What a place to stay! The view is breathtaking...
# 1      Search no further, this is the place to stay. ...
# 2      This was my second visit and it was as good as...
# 3      Thank you Dirk and your wife for wonderful wee...
# 4          Great place, great location and a great host.
# ...                                                  ...
# 11969  We were extremely comfortable during this visi...
# 11970  The apartment is brand new and definitely felt...
# 11971  I had an amazing stay in this very stylish apa...
# 11972  Anna's Camps Bay Retreat: ⭐⭐⭐⭐⭐<br/>Annas's ap...
# 11973  I will be back! <br/>What a beautiful apartmen...
#
#                                      translated_comments
# 0      What a place to stay! The view is breathtaking...
# 1      Search no further, this is the place to stay. ...
# 2      This was my second visit and it was as good as...
# 3      Thank you Dirk and your wife for wonderful wee...
# 4          Great place, great location and a great host.
# ...                                                  ...
# 11969  We were extremely comfortable during this visi...
# 11970  The apartment is brand new and definitely felt...
# 11971  I had an amazing stay in this very stylish apa...
# 11972  Anna's Camps Bay Retreat: ⭐⭐⭐⭐⭐<br/>Annas's ap...
# 11973  I will be back! <br/>What a beautiful apartmen...
#
# [11974 rows x 5 columns]

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Initialize the VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

"""
Uses VADER sentiment analysis to analyze comments and returns whether the review is 'good', 'neutral', or 'bad'.

Args:
    row (int): The row index number
    comment (string): The comment to analyze

Returns:
    string: 'good', 'neutral', or 'bad'
"""
def sentiment(row, comment):
    # Check if the comment is null or empty
    if pd.isnull(comment) or comment.strip() == "":
        return None

    print(f"Processing index {row}")
    try:
        # Analyze sentiment using VADER
        sentiment_score = analyzer.polarity_scores(comment)['compound']

        # Classify sentiment as 'good', 'neutral', or 'bad'
        if sentiment_score > 0.05:
            return 'good'
        elif sentiment_score < -0.05:
            return 'bad'
        else:
            return 'neutral'
    except Exception as e:
        print(f"Error at index {row}: {e}")
        return None  # or another appropriate fallback value

# Apply the function to the 'comments' column
reviews_df['sentiment'] = reviews_df.apply(lambda row: sentiment(row.name, row['translated_comments']), axis=1)
# Out:
# Streaming output truncated to the last 5000 lines.
# Processing index 6973
# Processing index 6974
# Processing index 6975
# Processing index 6976
# Processing index 6977
# Processing index 6978
# Processing index 6979
# Processing index 6980
# Processing index 6981
# Processing index 6982
# Processing index 6983
# Processing index 6984
# Processing index 6985
# Processing index 6986
# Processing index 6987
# Processing index 6988
# Processing index 6989
# Processing index 6990
# Processing index 6991
# Processing index 6992
# Processing index 6993
# Processing index 6994
# Processing index 6995
# Processing index 6996
# Processing index 6997
# Processing index 6998
# Processing index 6999
# Processing index 7000
# Processing index 7001
# Processing index 7002
# Processing index 7003
# Processing index 7004
# Processing index 7005
# Processing index 7006
# Processing index 7007
# Processing index 7008
# Processing index 7009
# Processing index 7010
# Processing index 7011
# Processing index 7012
# Processing index 7013
# Processing index 7014
# Processing index 7015
# Processing index 7016
# Processing index 7017
# Processing index 7018
# Processing index 7019
# Processing index 7020
# Processing index 7021
# Processing index 7022
# Processing index 7023
# Processing index 7024
# Processing index 7025
# Processing index 7026
# Processing index 7027
# Processing index 7028
# Processing index 7029
# Processing index 7030
# Processing index 7031
# Processing index 7032
# Processing index 7033
# Processing index 7034
# Processing index 7035
# Processing index 7036
# Processing index 7037
# Processing index 7038
# Processing index 7039
# Processing index 7040
# Processing index 7041
# Processing index 7042
# Processing index 7043
# Processing index 7044
# Processing index 7045
# Processing index 7046
# Processing index 7047
# Processing index 7048
# Processing index 7049
# Processing index 7050
# Processing index 7051
# Processing index 7052
# Processing index 7053
# Processing index 7054
# Processing index 7055
# Processing index 7056
# Processing index 7057
# Processing index 7058
# Processing index 7059
# Processing index 7060
# Processing index 7061
# Processing index 7062
# Processing index 7063
# Processing index 7064
# Processing index 7065
# Processing index 7066
# Processing index 7067
# Processing index 7068
# Processing index 7069
# Processing index 7070
# Processing index 7071
# Processing index 7072
# Processing index 7073
# Processing index 7074
# Processing index 7075
# Processing index 7076
# Processing index 7077
# Processing index 7078
# Processing index 7079
# Processing index 7080
# Processing index 7081
# Processing index 7082
# Processing index 7083
# Processing index 7084
# Processing index 7085
# Processing index 7086
# Processing index 7087
# Processing index 7088
# Processing index 7089
# Processing index 7090
# Processing index 7091
# Processing index 7092
# Processing index 7093
# Processing index 7094
# Processing index 7095
# Processing index 7096
# Processing index 7097
# Processing index 7098
# Processing index 7099
# Processing index 7100
# Processing index 7101
# Processing index 7102
# Processing index 7103
# Processing index 7104
# Processing index 7105
# Processing index 7106
# Processing index 7107
# Processing index 7108
# Processing index 7109
# Processing index 7110
# Processing index 7111
# Processing index 7112
# Processing index 7113
# Processing index 7114
# Processing index 7115
# Processing index 7116
# Processing index 7117
# Processing index 7118
# Processing index 7119
# Processing index 7120
# Processing index 7121
# Processing index 7122
# Processing index 7123
# Processing index 7124
# Processing index 7125
# Processing index 7126
# Processing index 7127
# Processing index 7128
# Processing index 7129
# Processing index 7130
# Processing index 7131
# Processing index 7132
# Processing index 7133
# Processing index 7134
# Processing index 7135
# Processing index 7136
# Processing index 7137
# Processing index 7138
# Processing index 7139
# Processing index 7140
# Processing index 7141
# Processing index 7142
# Processing index 7143
# Processing index 7144
# Processing index 7145
# Processing index 7146
# Processing index 7147
# Processing index 7148
# Processing index 7149
# Processing index 7150
# Processing index 7151
# Processing index 7152
# Processing index 7153
# Processing index 7154
# Processing index 7155
# Processing index 7156
# Processing index 7157
# Processing index 7158
# Processing index 7159
# Processing index 7160
# Processing index 7161
# Processing index 7162
# Processing index 7163
# Processing index 7164
# Processing index 7165
# Processing index 7166
# Processing index 7167
# Processing index 7168
# Processing index 7169
# Processing index 7170
# Processing index 7171
# Processing index 7172
# Processing index 7173
# Processing index 7174
# Processing index 7175
# Processing index 7176
# Processing index 7177
# Processing index 7178
# Processing index 7179
# Processing index 7180
# Processing index 7181
# Processing index 7182
# Processing index 7183
# Processing index 7184
# Processing index 7185
# Processing index 7186
# Processing index 7187
# Processing index 7188
# Processing index 7189
# Processing index 7190
# Processing index 7191
# Processing index 7192
# Processing index 7193
# Processing index 7194
# Processing index 7195
# Processing index 7196
# Processing index 7197
# Processing index 7198
# Processing index 7199
# Processing index 7200
# Processing index 7201
# Processing index 7202
# Processing index 7203
# Processing index 7204
# Processing index 7205
# Processing index 7206
# Processing index 7207
# Processing index 7208
# Processing index 7209
# Processing index 7210
# Processing index 7211
# Processing index 7212
# Processing index 7213
# Processing index 7214
# Processing index 7215
# Processing index 7216
# Processing index 7217
# Processing index 7218
# Processing index 7219
# Processing index 7220
# Processing index 7221
# Processing index 7222
# Processing index 7223
# Processing index 7224
# Processing index 7225
# Processing index 7226
# Processing index 7227
# Processing index 7228
# Processing index 7229
# Processing index 7230
# Processing index 7231
# Processing index 7232
# Processing index 7233
# Processing index 7234
# Processing index 7235
# Processing index 7236
# Processing index 7237
# Processing index 7238
# Processing index 7239
# Processing index 7240
# Processing index 7241
# Processing index 7242
# Processing index 7243
# Processing index 7244
# Processing index 7245
# Processing index 7246
# Processing index 7247
# Processing index 7248
# Processing index 7249
# Processing index 7250
# Processing index 7251
# Processing index 7252
# Processing index 7253
# Processing index 7254
# Processing index 7255
# Processing index 7256
# Processing index 7257
# Processing index 7258
# Processing index 7259
# Processing index 7260
# Processing index 7261
# Processing index 7262
# Processing index 7263
# Processing index 7264
# Processing index 7265
# Processing index 7266
# Processing index 7267
# Processing index 7268
# Processing index 7269
# Processing index 7270
# Processing index 7271
# Processing index 7272
# Processing index 7273
# Processing index 7274
# Processing index 7275
# Processing index 7276
# Processing index 7277
# Processing index 7278
# Processing index 7279
# Processing index 7280
# Processing index 7281
# Processing index 7282
# Processing index 7283
# Processing index 7284
# Processing index 7285
# Processing index 7286
# Processing index 7287
# Processing index 7288
# Processing index 7289
# Processing index 7290
# Processing index 7291
# Processing index 7292
# Processing index 7293
# Processing index 7294
# Processing index 7295
# Processing index 7296
# Processing index 7297
# Processing index 7298
# Processing index 7299
# Processing index 7300
# Processing index 7301
# Processing index 7302
# Processing index 7303
# Processing index 7304
# Processing index 7305
# Processing index 7306
# Processing index 7307
# Processing index 7308
# Processing index 7309
# Processing index 7310
# Processing index 7311
# Processing index 7312
# Processing index 7313
# Processing index 7314
# Processing index 7315
# Processing index 7316
# Processing index 7317
# Processing index 7318
# Processing index 7319
# Processing index 7320
# Processing index 7321
# Processing index 7322
# Processing index 7323
# Processing index 7324
# Processing index 7325
# Processing index 7326
# Processing index 7327
# Processing index 7328
# Processing index 7329
# Processing index 7330
# Processing index 7331
# Processing index 7332
# Processing index 7333
# Processing index 7334
# Processing index 7335
# Processing index 7336
# Processing index 7337
# Processing index 7338
# Processing index 7339
# Processing index 7340
# Processing index 7341
# Processing index 7342
# Processing index 7343
# Processing index 7344
# Processing index 7345
# Processing index 7346
# Processing index 7347
# Processing index 7348
# Processing index 7349
# Processing index 7350
# Processing index 7351
# Processing index 7352
# Processing index 7353
# Processing index 7354
# Processing index 7355
# Processing index 7356
# Processing index 7357
# Processing index 7358
# Processing index 7359
# Processing index 7360
# Processing index 7361
# Processing index 7362
# Processing index 7363
# Processing index 7364
# Processing index 7365
# Processing index 7366
# Processing index 7367
# Processing index 7368
# Processing index 7369
# Processing index 7370
# Processing index 7371
# Processing index 7372
# Processing index 7373
# Processing index 7374
# Processing index 7375
# Processing index 7376
# Processing index 7377
# Processing index 7378
# Processing index 7379
# Processing index 7380
# Processing index 7381
# Processing index 7382
# Processing index 7383
# Processing index 7384
# Processing index 7385
# Processing index 7386
# Processing index 7387
# Processing index 7388
# Processing index 7389
# Processing index 7390
# Processing index 7391
# Processing index 7392
# Processing index 7393
# Processing index 7394
# Processing index 7395
# Processing index 7396
# Processing index 7397
# Processing index 7398
# Processing index 7399
# Processing index 7400
# Processing index 7401
# Processing index 7402
# Processing index 7403
# Processing index 7404
# Processing index 7405
# Processing index 7406
# Processing index 7407
# Processing index 7408
# Processing index 7409
# Processing index 7410
# Processing index 7411
# Processing index 7412
# Processing index 7413
# Processing index 7414
# Processing index 7415
# Processing index 7416
# Processing index 7417
# Processing index 7418
# Processing index 7419
# Processing index 7420
# Processing index 7421
# Processing index 7422
# Processing index 7423
# Processing index 7424
# Processing index 7425
# Processing index 7426
# Processing index 7427
# Processing index 7428
# Processing index 7429
# Processing index 7430
# Processing index 7431
# Processing index 7432
# Processing index 7433
# Processing index 7434
# Processing index 7435
# Processing index 7436
# Processing index 7437
# Processing index 7438
# Processing index 7439
# Processing index 7440
# Processing index 7441
# Processing index 7442
# Processing index 7443
# Processing index 7444
# Processing index 7445
# Processing index 7446
# Processing index 7447
# Processing index 7448
# Processing index 7449
# Processing index 7450
# Processing index 7451
# Processing index 7452
# Processing index 7453
# Processing index 7454
# Processing index 7455
# Processing index 7456
# Processing index 7457
# Processing index 7458
# Processing index 7459
# Processing index 7460
# Processing index 7461
# Processing index 7462
# Processing index 7463
# Processing index 7464
# Processing index 7465
# Processing index 7466
# Processing index 7467
# Processing index 7468
# Processing index 7469
# Processing index 7470
# Processing index 7471
# Processing index 7472
# Processing index 7473
# Processing index 7474
# Processing index 7475
# Processing index 7476
# Processing index 7477
# Processing index 7478
# Processing index 7479
# Processing index 7480
# Processing index 7481
# Processing index 7482
# Processing index 7483
# Processing index 7484
# Processing index 7485
# Processing index 7486
# Processing index 7487
# Processing index 7488
# Processing index 7489
# Processing index 7490
# Processing index 7491
# Processing index 7492
# Processing index 7493
# Processing index 7494
# Processing index 7495
# Processing index 7496
# Processing index 7497
# Processing index 7498
# Processing index 7499
# Processing index 7500
# Processing index 7501
# Processing index 7502
# Processing index 7503
# Processing index 7504
# Processing index 7505
# Processing index 7506
# Processing index 7507
# Processing index 7508
# Processing index 7509
# Processing index 7510
# Processing index 7511
# Processing index 7512
# Processing index 7513
# Processing index 7514
# Processing index 7515
# Processing index 7516
# Processing index 7517
# Processing index 7518
# Processing index 7519
# Processing index 7520
# Processing index 7521
# Processing index 7522
# Processing index 7523
# Processing index 7524
# Processing index 7525
# Processing index 7526
# Processing index 7527
# Processing index 7528
# Processing index 7529
# Processing index 7530
# Processing index 7531
# Processing index 7532
# Processing index 7533
# Processing index 7534
# Processing index 7535
# Processing index 7536
# Processing index 7537
# Processing index 7538
# Processing index 7539
# Processing index 7540
# Processing index 7541
# Processing index 7542
# Processing index 7543
# Processing index 7544
# Processing index 7545
# Processing index 7546
# Processing index 7547
# Processing index 7548
# Processing index 7549
# Processing index 7550
# Processing index 7551
# Processing index 7552
# Processing index 7553
# Processing index 7554
# Processing index 7555
# Processing index 7556
# Processing index 7557
# Processing index 7558
# Processing index 7559
# Processing index 7560
# Processing index 7561
# Processing index 7562
# Processing index 7563
# Processing index 7564
# Processing index 7565
# Processing index 7566
# Processing index 7567
# Processing index 7568
# Processing index 7569
# Processing index 7570
# Processing index 7571
# Processing index 7572
# Processing index 7573
# Processing index 7574
# Processing index 7575
# Processing index 7576
# Processing index 7577
# Processing index 7578
# Processing index 7579
# Processing index 7580
# Processing index 7581
# Processing index 7582
# Processing index 7583
# Processing index 7584
# Processing index 7585
# Processing index 7586
# Processing index 7587
# Processing index 7588
# Processing index 7589
# Processing index 7590
# Processing index 7591
# Processing index 7592
# Processing index 7593
# Processing index 7594
# Processing index 7595
# Processing index 7596
# Processing index 7597
# Processing index 7598
# Processing index 7599
# Processing index 7600
# Processing index 7601
# Processing index 7602
# Processing index 7603
# Processing index 7604
# Processing index 7605
# Processing index 7606
# Processing index 7607
# Processing index 7608
# Processing index 7609
# Processing index 7610
# Processing index 7611
# Processing index 7612
# Processing index 7613
# Processing index 7614
# Processing index 7615
# Processing index 7616
# Processing index 7617
# Processing index 7618
# Processing index 7619
# Processing index 7620
# Processing index 7621
# Processing index 7622
# Processing index 7623
# Processing index 7624
# Processing index 7625
# Processing index 7626
# Processing index 7627
# Processing index 7628
# Processing index 7629
# Processing index 7630
# Processing index 7631
# Processing index 7632
# Processing index 7633
# Processing index 7634
# Processing index 7635
# Processing index 7636
# Processing index 7637
# Processing index 7638
# Processing index 7639
# Processing index 7640
# Processing index 7641
# Processing index 7642
# Processing index 7643
# Processing index 7644
# Processing index 7645
# Processing index 7646
# Processing index 7647
# Processing index 7648
# Processing index 7649
# Processing index 7650
# Processing index 7651
# Processing index 7652
# Processing index 7653
# Processing index 7654
# Processing index 7655
# Processing index 7656
# Processing index 7657
# Processing index 7658
# Processing index 7659
# Processing index 7660
# Processing index 7661
# Processing index 7662
# Processing index 7663
# Processing index 7664
# Processing index 7665
# Processing index 7666
# Processing index 7667
# Processing index 7668
# Processing index 7669
# Processing index 7670
# Processing index 7671
# Processing index 7672
# Processing index 7673
# Processing index 7674
# Processing index 7675
# Processing index 7676
# Processing index 7677
# Processing index 7678
# Processing index 7679
# Processing index 7680
# Processing index 7681
# Processing index 7682
# Processing index 7683
# Processing index 7684
# Processing index 7685
# Processing index 7686
# Processing index 7687
# Processing index 7688
# Processing index 7689
# Processing index 7690
# Processing index 7691
# Processing index 7692
# Processing index 7693
# Processing index 7694
# Processing index 7695
# Processing index 7696
# Processing index 7697
# Processing index 7698
# Processing index 7699
# Processing index 7700
# Processing index 7701
# Processing index 7702
# Processing index 7703
# Processing index 7704
# Processing index 7705
# Processing index 7706
# Processing index 7707
# Processing index 7708
# Processing index 7709
# Processing index 7710
# Processing index 7711
# Processing index 7712
# Processing index 7713
# Processing index 7714
# Processing index 7715
# Processing index 7716
# Processing index 7717
# Processing index 7718
# Processing index 7719
# Processing index 7720
# Processing index 7721
# Processing index 7722
# Processing index 7723
# Processing index 7724
# Processing index 7725
# Processing index 7726
# Processing index 7727
# Processing index 7728
# Processing index 7729
# Processing index 7730
# Processing index 7731
# Processing index 7732
# Processing index 7733
# Processing index 7734
# Processing index 7735
# Processing index 7736
# Processing index 7737
# Processing index 7738
# Processing index 7739
# Processing index 7740
# Processing index 7741
# Processing index 7742
# Processing index 7743
# Processing index 7744
# Processing index 7745
# Processing index 7746
# Processing index 7747
# Processing index 7748
# Processing index 7749
# Processing index 7750
# Processing index 7751
# Processing index 7752
# Processing index 7753
# Processing index 7754
# Processing index 7755
# Processing index 7756
# Processing index 7757
# Processing index 7758
# Processing index 7759
# Processing index 7760
# Processing index 7761
# Processing index 7762
# Processing index 7763
# Processing index 7764
# Processing index 7765
# Processing index 7766
# Processing index 7767
# Processing index 7768
# Processing index 7769
# Processing index 7770
# Processing index 7771
# Processing index 7772
# Processing index 7773
# Processing index 7774
# Processing index 7775
# Processing index 7776
# Processing index 7777
# Processing index 7778
# Processing index 7779
# Processing index 7780
# Processing index 7781
# Processing index 7782
# Processing index 7783
# Processing index 7784
# Processing index 7785
# Processing index 7786
# Processing index 7787
# Processing index 7788
# Processing index 7789
# Processing index 7790
# Processing index 7791
# Processing index 7792
# Processing index 7794
# Processing index 7795
# Processing index 7796
# Processing index 7797
# Processing index 7798
# Processing index 7799
# Processing index 7800
# Processing index 7801
# Processing index 7802
# Processing index 7803
# Processing index 7804
# Processing index 7805
# Processing index 7806
# Processing index 7807
# Processing index 7808
# Processing index 7809
# Processing index 7810
# Processing index 7811
# Processing index 7812
# Processing index 7813
# Processing index 7814
# Processing index 7815
# Processing index 7816
# Processing index 7817
# Processing index 7818
# Processing index 7819
# Processing index 7820
# Processing index 7821
# Processing index 7822
# Processing index 7823
# Processing index 7824
# Processing index 7825
# Processing index 7826
# Processing index 7827
# Processing index 7828
# Processing index 7829
# Processing index 7830
# Processing index 7831
# Processing index 7832
# Processing index 7833
# Processing index 7834
# Processing index 7835
# Processing index 7836
# Processing index 7837
# Processing index 7838
# Processing index 7839
# Processing index 7840
# Processing index 7841
# Processing index 7842
# Processing index 7843
# Processing index 7844
# Processing index 7845
# Processing index 7846
# Processing index 7847
# Processing index 7848
# Processing index 7849
# Processing index 7850
# Processing index 7851
# Processing index 7852
# Processing index 7853
# Processing index 7854
# Processing index 7855
# Processing index 7856
# Processing index 7857
# Processing index 7858
# Processing index 7859
# Processing index 7860
# Processing index 7861
# Processing index 7862
# Processing index 7863
# Processing index 7864
# Processing index 7865
# Processing index 7866
# Processing index 7867
# Processing index 7868
# Processing index 7869
# Processing index 7870
# Processing index 7871
# Processing index 7872
# Processing index 7873
# Processing index 7874
# Processing index 7875
# Processing index 7876
# Processing index 7877
# Processing index 7878
# Processing index 7879
# Processing index 7880
# Processing index 7881
# Processing index 7882
# Processing index 7883
# Processing index 7884
# Processing index 7885
# Processing index 7886
# Processing index 7887
# Processing index 7888
# Processing index 7889
# Processing index 7890
# Processing index 7891
# Processing index 7892
# Processing index 7893
# Processing index 7894
# Processing index 7895
# Processing index 7896
# Processing index 7897
# Processing index 7898
# Processing index 7899
# Processing index 7900
# Processing index 7901
# Processing index 7902
# Processing index 7903
# Processing index 7904
# Processing index 7905
# Processing index 7906
# Processing index 7907
# Processing index 7908
# Processing index 7909
# Processing index 7910
# Processing index 7911
# Processing index 7912
# Processing index 7913
# Processing index 7914
# Processing index 7915
# Processing index 7916
# Processing index 7917
# Processing index 7918
# Processing index 7919
# Processing index 7920
# Processing index 7921
# Processing index 7922
# Processing index 7923
# Processing index 7924
# Processing index 7925
# Processing index 7926
# Processing index 7927
# Processing index 7928
# Processing index 7929
# Processing index 7930
# Processing index 7931
# Processing index 7932
# Processing index 7933
# Processing index 7934
# Processing index 7935
# Processing index 7936
# Processing index 7937
# Processing index 7938
# Processing index 7939
# Processing index 7940
# Processing index 7941
# Processing index 7942
# Processing index 7943
# Processing index 7944
# Processing index 7945
# Processing index 7946
# Processing index 7947
# Processing index 7948
# Processing index 7949
# Processing index 7950
# Processing index 7951
# Processing index 7952
# Processing index 7953
# Processing index 7954
# Processing index 7955
# Processing index 7956
# Processing index 7957
# Processing index 7958
# Processing index 7959
# Processing index 7960
# Processing index 7961
# Processing index 7962
# Processing index 7963
# Processing index 7964
# Processing index 7965
# Processing index 7966
# Processing index 7967
# Processing index 7968
# Processing index 7969
# Processing index 7970
# Processing index 7971
# Processing index 7972
# Processing index 7973
# Processing index 7974
# Processing index 7975
# Processing index 7976
# Processing index 7977
# Processing index 7978
# Processing index 7979
# Processing index 7980
# Processing index 7981
# Processing index 7982
# Processing index 7983
# Processing index 7984
# Processing index 7985
# Processing index 7986
# Processing index 7987
# Processing index 7988
# Processing index 7989
# Processing index 7990
# Processing index 7991
# Processing index 7992
# Processing index 7993
# Processing index 7994
# Processing index 7995
# Processing index 7996
# Processing index 7997
# Processing index 7998
# Processing index 7999
# Processing index 8000
# Processing index 8001
# Processing index 8002
# Processing index 8003
# Processing index 8004
# Processing index 8005
# Processing index 8006
# Processing index 8007
# Processing index 8008
# Processing index 8009
# Processing index 8010
# Processing index 8011
# Processing index 8012
# Processing index 8013
# Processing index 8014
# Processing index 8015
# Processing index 8016
# Processing index 8017
# Processing index 8018
# Processing index 8019
# Processing index 8020
# Processing index 8021
# Processing index 8022
# Processing index 8023
# Processing index 8024
# Processing index 8025
# Processing index 8026
# Processing index 8027
# Processing index 8028
# Processing index 8029
# Processing index 8030
# Processing index 8031
# Processing index 8032
# Processing index 8033
# Processing index 8034
# Processing index 8035
# Processing index 8036
# Processing index 8037
# Processing index 8038
# Processing index 8039
# Processing index 8040
# Processing index 8041
# Processing index 8042
# Processing index 8043
# Processing index 8044
# Processing index 8045
# Processing index 8046
# Processing index 8047
# Processing index 8048
# Processing index 8049
# Processing index 8050
# Processing index 8051
# Processing index 8052
# Processing index 8053
# Processing index 8054
# Processing index 8055
# Processing index 8056
# Processing index 8057
# Processing index 8058
# Processing index 8059
# Processing index 8060
# Processing index 8061
# Processing index 8062
# Processing index 8063
# Processing index 8064
# Processing index 8065
# Processing index 8066
# Processing index 8067
# Processing index 8068
# Processing index 8069
# Processing index 8070
# Processing index 8071
# Processing index 8072
# Processing index 8073
# Processing index 8074
# Processing index 8075
# Processing index 8076
# Processing index 8077
# Processing index 8078
# Processing index 8079
# Processing index 8080
# Processing index 8081
# Processing index 8082
# Processing index 8083
# Processing index 8084
# Processing index 8085
# Processing index 8086
# Processing index 8087
# Processing index 8088
# Processing index 8089
# Processing index 8090
# Processing index 8091
# Processing index 8092
# Processing index 8093
# Processing index 8094
# Processing index 8095
# Processing index 8096
# Processing index 8097
# Processing index 8098
# Processing index 8099
# Processing index 8100
# Processing index 8101
# Processing index 8102
# Processing index 8103
# Processing index 8104
# Processing index 8105
# Processing index 8106
# Processing index 8107
# Processing index 8108
# Processing index 8109
# Processing index 8110
# Processing index 8111
# Processing index 8112
# Processing index 8113
# Processing index 8114
# Processing index 8115
# Processing index 8116
# Processing index 8117
# Processing index 8118
# Processing index 8119
# Processing index 8120
# Processing index 8121
# Processing index 8122
# Processing index 8123
# Processing index 8124
# Processing index 8125
# Processing index 8126
# Processing index 8127
# Processing index 8128
# Processing index 8129
# Processing index 8130
# Processing index 8131
# Processing index 8132
# Processing index 8133
# Processing index 8134
# Processing index 8135
# Processing index 8136
# Processing index 8137
# Processing index 8138
# Processing index 8139
# Processing index 8140
# Processing index 8141
# Processing index 8142
# Processing index 8143
# Processing index 8144
# Processing index 8145
# Processing index 8146
# Processing index 8147
# Processing index 8148
# Processing index 8149
# Processing index 8150
# Processing index 8151
# Processing index 8152
# Processing index 8153
# Processing index 8154
# Processing index 8155
# Processing index 8156
# Processing index 8157
# Processing index 8158
# Processing index 8159
# Processing index 8160
# Processing index 8161
# Processing index 8162
# Processing index 8163
# Processing index 8164
# Processing index 8165
# Processing index 8166
# Processing index 8167
# Processing index 8168
# Processing index 8169
# Processing index 8170
# Processing index 8171
# Processing index 8172
# Processing index 8173
# Processing index 8174
# Processing index 8175
# Processing index 8176
# Processing index 8177
# Processing index 8178
# Processing index 8179
# Processing index 8180
# Processing index 8181
# Processing index 8182
# Processing index 8183
# Processing index 8184
# Processing index 8185
# Processing index 8186
# Processing index 8187
# Processing index 8188
# Processing index 8189
# Processing index 8190
# Processing index 8191
# Processing index 8192
# Processing index 8193
# Processing index 8194
# Processing index 8195
# Processing index 8196
# Processing index 8197
# Processing index 8198
# Processing index 8199
# Processing index 8200
# Processing index 8201
# Processing index 8202
# Processing index 8203
# Processing index 8204
# Processing index 8205
# Processing index 8206
# Processing index 8207
# Processing index 8208
# Processing index 8209
# Processing index 8210
# Processing index 8211
# Processing index 8212
# Processing index 8213
# Processing index 8214
# Processing index 8215
# Processing index 8216
# Processing index 8217
# Processing index 8218
# Processing index 8219
# Processing index 8220
# Processing index 8221
# Processing index 8222
# Processing index 8223
# Processing index 8224
# Processing index 8225
# Processing index 8226
# Processing index 8227
# Processing index 8228
# Processing index 8229
# Processing index 8230
# Processing index 8231
# Processing index 8232
# Processing index 8233
# Processing index 8234
# Processing index 8235
# Processing index 8236
# Processing index 8237
# Processing index 8238
# Processing index 8239
# Processing index 8240
# Processing index 8241
# Processing index 8242
# Processing index 8243
# Processing index 8244
# Processing index 8245
# Processing index 8246
# Processing index 8247
# Processing index 8248
# Processing index 8249
# Processing index 8250
# Processing index 8251
# Processing index 8252
# Processing index 8253
# Processing index 8254
# Processing index 8255
# Processing index 8256
# Processing index 8257
# Processing index 8258
# Processing index 8259
# Processing index 8260
# Processing index 8261
# Processing index 8262
# Processing index 8263
# Processing index 8264
# Processing index 8265
# Processing index 8266
# Processing index 8267
# Processing index 8268
# Processing index 8269
# Processing index 8270
# Processing index 8271
# Processing index 8272
# Processing index 8273
# Processing index 8274
# Processing index 8275
# Processing index 8276
# Processing index 8277
# Processing index 8278
# Processing index 8279
# Processing index 8280
# Processing index 8281
# Processing index 8282
# Processing index 8283
# Processing index 8284
# Processing index 8285
# Processing index 8286
# Processing index 8287
# Processing index 8288
# Processing index 8289
# Processing index 8290
# Processing index 8291
# Processing index 8292
# Processing index 8293
# Processing index 8294
# Processing index 8295
# Processing index 8296
# Processing index 8297
# Processing index 8298
# Processing index 8299
# Processing index 8300
# Processing index 8301
# Processing index 8302
# Processing index 8303
# Processing index 8304
# Processing index 8305
# Processing index 8306
# Processing index 8307
# Processing index 8308
# Processing index 8309
# Processing index 8310
# Processing index 8311
# Processing index 8312
# Processing index 8313
# Processing index 8314
# Processing index 8315
# Processing index 8316
# Processing index 8317
# Processing index 8318
# Processing index 8319
# Processing index 8320
# Processing index 8321
# Processing index 8322
# Processing index 8323
# Processing index 8324
# Processing index 8325
# Processing index 8326
# Processing index 8327
# Processing index 8328
# Processing index 8329
# Processing index 8330
# Processing index 8331
# Processing index 8332
# Processing index 8333
# Processing index 8334
# Processing index 8335
# Processing index 8336
# Processing index 8337
# Processing index 8338
# Processing index 8339
# Processing index 8340
# Processing index 8341
# Processing index 8342
# Processing index 8343
# Processing index 8344
# Processing index 8345
# Processing index 8346
# Processing index 8347
# Processing index 8348
# Processing index 8349
# Processing index 8350
# Processing index 8351
# Processing index 8352
# Processing index 8353
# Processing index 8354
# Processing index 8355
# Processing index 8356
# Processing index 8357
# Processing index 8358
# Processing index 8359
# Processing index 8360
# Processing index 8361
# Processing index 8362
# Processing index 8363
# Processing index 8364
# Processing index 8365
# Processing index 8366
# Processing index 8367
# Processing index 8368
# Processing index 8369
# Processing index 8370
# Processing index 8371
# Processing index 8372
# Processing index 8373
# Processing index 8374
# Processing index 8375
# Processing index 8376
# Processing index 8377
# Processing index 8378
# Processing index 8379
# Processing index 8380
# Processing index 8381
# Processing index 8382
# Processing index 8383
# Processing index 8384
# Processing index 8385
# Processing index 8386
# Processing index 8387
# Processing index 8388
# Processing index 8389
# Processing index 8390
# Processing index 8391
# Processing index 8392
# Processing index 8393
# Processing index 8394
# Processing index 8395
# Processing index 8396
# Processing index 8397
# Processing index 8398
# Processing index 8399
# Processing index 8400
# Processing index 8401
# Processing index 8402
# Processing index 8403
# Processing index 8404
# Processing index 8405
# Processing index 8406
# Processing index 8407
# Processing index 8408
# Processing index 8409
# Processing index 8410
# Processing index 8411
# Processing index 8412
# Processing index 8413
# Processing index 8414
# Processing index 8415
# Processing index 8416
# Processing index 8417
# Processing index 8418
# Processing index 8419
# Processing index 8420
# Processing index 8421
# Processing index 8422
# Processing index 8423
# Processing index 8424
# Processing index 8425
# Processing index 8426
# Processing index 8427
# Processing index 8428
# Processing index 8429
# Processing index 8430
# Processing index 8431
# Processing index 8432
# Processing index 8433
# Processing index 8434
# Processing index 8435
# Processing index 8436
# Processing index 8437
# Processing index 8438
# Processing index 8439
# Processing index 8440
# Processing index 8441
# Processing index 8442
# Processing index 8443
# Processing index 8444
# Processing index 8445
# Processing index 8446
# Processing index 8447
# Processing index 8448
# Processing index 8449
# Processing index 8450
# Processing index 8451
# Processing index 8452
# Processing index 8453
# Processing index 8454
# Processing index 8455
# Processing index 8456
# Processing index 8457
# Processing index 8458
# Processing index 8459
# Processing index 8460
# Processing index 8461
# Processing index 8462
# Processing index 8463
# Processing index 8464
# Processing index 8465
# Processing index 8466
# Processing index 8467
# Processing index 8468
# Processing index 8469
# Processing index 8470
# Processing index 8471
# Processing index 8472
# Processing index 8473
# Processing index 8474
# Processing index 8475
# Processing index 8476
# Processing index 8477
# Processing index 8478
# Processing index 8479
# Processing index 8480
# Processing index 8481
# Processing index 8482
# Processing index 8483
# Processing index 8484
# Processing index 8485
# Processing index 8486
# Processing index 8487
# Processing index 8488
# Processing index 8489
# Processing index 8490
# Processing index 8491
# Processing index 8492
# Processing index 8493
# Processing index 8494
# Processing index 8495
# Processing index 8496
# Processing index 8497
# Processing index 8498
# Processing index 8499
# Processing index 8500
# Processing index 8501
# Processing index 8502
# Processing index 8503
# Processing index 8504
# Processing index 8505
# Processing index 8506
# Processing index 8507
# Processing index 8508
# Processing index 8509
# Processing index 8510
# Processing index 8511
# Processing index 8512
# Processing index 8513
# Processing index 8514
# Processing index 8515
# Processing index 8516
# Processing index 8517
# Processing index 8518
# Processing index 8519
# Processing index 8520
# Processing index 8521
# Processing index 8522
# Processing index 8523
# Processing index 8524
# Processing index 8525
# Processing index 8526
# Processing index 8527
# Processing index 8528
# Processing index 8529
# Processing index 8530
# Processing index 8531
# Processing index 8532
# Processing index 8533
# Processing index 8534
# Processing index 8535
# Processing index 8536
# Processing index 8537
# Processing index 8538
# Processing index 8539
# Processing index 8540
# Processing index 8541
# Processing index 8542
# Processing index 8543
# Processing index 8544
# Processing index 8545
# Processing index 8546
# Processing index 8547
# Processing index 8548
# Processing index 8549
# Processing index 8550
# Processing index 8551
# Processing index 8552
# Processing index 8553
# Processing index 8554
# Processing index 8555
# Processing index 8556
# Processing index 8557
# Processing index 8558
# Processing index 8559
# Processing index 8560
# Processing index 8561
# Processing index 8562
# Processing index 8563
# Processing index 8564
# Processing index 8565
# Processing index 8566
# Processing index 8567
# Processing index 8568
# Processing index 8569
# Processing index 8570
# Processing index 8571
# Processing index 8572
# Processing index 8573
# Processing index 8574
# Processing index 8575
# Processing index 8576
# Processing index 8577
# Processing index 8578
# Processing index 8579
# Processing index 8580
# Processing index 8581
# Processing index 8582
# Processing index 8583
# Processing index 8584
# Processing index 8585
# Processing index 8586
# Processing index 8587
# Processing index 8588
# Processing index 8589
# Processing index 8590
# Processing index 8591
# Processing index 8592
# Processing index 8593
# Processing index 8594
# Processing index 8595
# Processing index 8596
# Processing index 8597
# Processing index 8598
# Processing index 8599
# Processing index 8600
# Processing index 8601
# Processing index 8602
# Processing index 8603
# Processing index 8604
# Processing index 8605
# Processing index 8606
# Processing index 8607
# Processing index 8608
# Processing index 8609
# Processing index 8610
# Processing index 8611
# Processing index 8612
# Processing index 8613
# Processing index 8614
# Processing index 8615
# Processing index 8616
# Processing index 8617
# Processing index 8618
# Processing index 8619
# Processing index 8620
# Processing index 8621
# Processing index 8622
# Processing index 8623
# Processing index 8624
# Processing index 8625
# Processing index 8626
# Processing index 8627
# Processing index 8628
# Processing index 8629
# Processing index 8630
# Processing index 8631
# Processing index 8632
# Processing index 8633
# Processing index 8634
# Processing index 8635
# Processing index 8636
# Processing index 8637
# Processing index 8638
# Processing index 8639
# Processing index 8640
# Processing index 8641
# Processing index 8642
# Processing index 8643
# Processing index 8644
# Processing index 8645
# Processing index 8646
# Processing index 8647
# Processing index 8648
# Processing index 8649
# Processing index 8650
# Processing index 8651
# Processing index 8652
# Processing index 8653
# Processing index 8654
# Processing index 8655
# Processing index 8656
# Processing index 8657
# Processing index 8658
# Processing index 8659
# Processing index 8660
# Processing index 8661
# Processing index 8662
# Processing index 8663
# Processing index 8664
# Processing index 8665
# Processing index 8666
# Processing index 8667
# Processing index 8668
# Processing index 8669
# Processing index 8670
# Processing index 8671
# Processing index 8672
# Processing index 8673
# Processing index 8674
# Processing index 8675
# Processing index 8676
# Processing index 8677
# Processing index 8678
# Processing index 8679
# Processing index 8680
# Processing index 8681
# Processing index 8682
# Processing index 8683
# Processing index 8684
# Processing index 8685
# Processing index 8686
# Processing index 8687
# Processing index 8688
# Processing index 8689
# Processing index 8690
# Processing index 8691
# Processing index 8692
# Processing index 8693
# Processing index 8694
# Processing index 8695
# Processing index 8696
# Processing index 8697
# Processing index 8698
# Processing index 8699
# Processing index 8700
# Processing index 8701
# Processing index 8702
# Processing index 8703
# Processing index 8704
# Processing index 8705
# Processing index 8706
# Processing index 8707
# Processing index 8708
# Processing index 8709
# Processing index 8710
# Processing index 8711
# Processing index 8712
# Processing index 8713
# Processing index 8714
# Processing index 8715
# Processing index 8716
# Processing index 8717
# Processing index 8718
# Processing index 8719
# Processing index 8720
# Processing index 8721
# Processing index 8722
# Processing index 8723
# Processing index 8724
# Processing index 8725
# Processing index 8726
# Processing index 8727
# Processing index 8728
# Processing index 8729
# Processing index 8730
# Processing index 8731
# Processing index 8732
# Processing index 8733
# Processing index 8734
# Processing index 8735
# Processing index 8736
# Processing index 8737
# Processing index 8738
# Processing index 8739
# Processing index 8740
# Processing index 8741
# Processing index 8742
# Processing index 8743
# Processing index 8744
# Processing index 8745
# Processing index 8746
# Processing index 8747
# Processing index 8748
# Processing index 8749
# Processing index 8750
# Processing index 8751
# Processing index 8752
# Processing index 8753
# Processing index 8754
# Processing index 8755
# Processing index 8756
# Processing index 8757
# Processing index 8758
# Processing index 8759
# Processing index 8760
# Processing index 8761
# Processing index 8762
# Processing index 8763
# Processing index 8764
# Processing index 8765
# Processing index 8766
# Processing index 8767
# Processing index 8768
# Processing index 8769
# Processing index 8770
# Processing index 8771
# Processing index 8772
# Processing index 8773
# Processing index 8774
# Processing index 8775
# Processing index 8776
# Processing index 8777
# Processing index 8778
# Processing index 8779
# Processing index 8780
# Processing index 8781
# Processing index 8782
# Processing index 8783
# Processing index 8784
# Processing index 8785
# Processing index 8786
# Processing index 8787
# Processing index 8788
# Processing index 8789
# Processing index 8790
# Processing index 8791
# Processing index 8792
# Processing index 8793
# Processing index 8794
# Processing index 8795
# Processing index 8796
# Processing index 8797
# Processing index 8798
# Processing index 8799
# Processing index 8800
# Processing index 8801
# Processing index 8802
# Processing index 8803
# Processing index 8804
# Processing index 8805
# Processing index 8806
# Processing index 8807
# Processing index 8808
# Processing index 8809
# Processing index 8810
# Processing index 8811
# Processing index 8812
# Processing index 8813
# Processing index 8814
# Processing index 8815
# Processing index 8816
# Processing index 8817
# Processing index 8818
# Processing index 8819
# Processing index 8820
# Processing index 8821
# Processing index 8822
# Processing index 8823
# Processing index 8824
# Processing index 8825
# Processing index 8826
# Processing index 8827
# Processing index 8828
# Processing index 8829
# Processing index 8830
# Processing index 8831
# Processing index 8832
# Processing index 8833
# Processing index 8834
# Processing index 8835
# Processing index 8836
# Processing index 8837
# Processing index 8838
# Processing index 8839
# Processing index 8840
# Processing index 8841
# Processing index 8842
# Processing index 8843
# Processing index 8844
# Processing index 8845
# Processing index 8846
# Processing index 8847
# Processing index 8848
# Processing index 8849
# Processing index 8850
# Processing index 8851
# Processing index 8852
# Processing index 8853
# Processing index 8854
# Processing index 8855
# Processing index 8856
# Processing index 8857
# Processing index 8858
# Processing index 8859
# Processing index 8860
# Processing index 8861
# Processing index 8862
# Processing index 8863
# Processing index 8864
# Processing index 8865
# Processing index 8866
# Processing index 8867
# Processing index 8868
# Processing index 8869
# Processing index 8870
# Processing index 8871
# Processing index 8872
# Processing index 8873
# Processing index 8874
# Processing index 8875
# Processing index 8876
# Processing index 8877
# Processing index 8878
# Processing index 8879
# Processing index 8880
# Processing index 8881
# Processing index 8882
# Processing index 8883
# Processing index 8884
# Processing index 8885
# Processing index 8886
# Processing index 8887
# Processing index 8888
# Processing index 8889
# Processing index 8890
# Processing index 8891
# Processing index 8892
# Processing index 8893
# Processing index 8894
# Processing index 8895
# Processing index 8896
# Processing index 8897
# Processing index 8898
# Processing index 8899
# Processing index 8900
# Processing index 8901
# Processing index 8902
# Processing index 8903
# Processing index 8904
# Processing index 8905
# Processing index 8906
# Processing index 8907
# Processing index 8908
# Processing index 8909
# Processing index 8910
# Processing index 8911
# Processing index 8912
# Processing index 8913
# Processing index 8914
# Processing index 8915
# Processing index 8916
# Processing index 8917
# Processing index 8918
# Processing index 8919
# Processing index 8920
# Processing index 8921
# Processing index 8922
# Processing index 8923
# Processing index 8924
# Processing index 8925
# Processing index 8926
# Processing index 8927
# Processing index 8928
# Processing index 8929
# Processing index 8930
# Processing index 8931
# Processing index 8932
# Processing index 8933
# Processing index 8934
# Processing index 8935
# Processing index 8936
# Processing index 8937
# Processing index 8938
# Processing index 8939
# Processing index 8940
# Processing index 8941
# Processing index 8942
# Processing index 8943
# Processing index 8944
# Processing index 8945
# Processing index 8946
# Processing index 8947
# Processing index 8948
# Processing index 8949
# Processing index 8950
# Processing index 8951
# Processing index 8952
# Processing index 8953
# Processing index 8954
# Processing index 8955
# Processing index 8956
# Processing index 8957
# Processing index 8958
# Processing index 8959
# Processing index 8960
# Processing index 8961
# Processing index 8962
# Processing index 8963
# Processing index 8964
# Processing index 8965
# Processing index 8966
# Processing index 8967
# Processing index 8968
# Processing index 8969
# Processing index 8970
# Processing index 8971
# Processing index 8972
# Processing index 8973
# Processing index 8974
# Processing index 8975
# Processing index 8976
# Processing index 8977
# Processing index 8978
# Processing index 8979
# Processing index 8980
# Processing index 8981
# Processing index 8982
# Processing index 8983
# Processing index 8984
# Processing index 8985
# Processing index 8986
# Processing index 8987
# Processing index 8988
# Processing index 8989
# Processing index 8990
# Processing index 8991
# Processing index 8992
# Processing index 8993
# Processing index 8994
# Processing index 8995
# Processing index 8996
# Processing index 8997
# Processing index 8998
# Processing index 8999
# Processing index 9000
# Processing index 9001
# Processing index 9002
# Processing index 9003
# Processing index 9004
# Processing index 9005
# Processing index 9006
# Processing index 9007
# Processing index 9008
# Processing index 9009
# Processing index 9010
# Processing index 9011
# Processing index 9012
# Processing index 9013
# Processing index 9014
# Processing index 9015
# Processing index 9016
# Processing index 9017
# Processing index 9018
# Processing index 9019
# Processing index 9020
# Processing index 9021
# Processing index 9022
# Processing index 9023
# Processing index 9024
# Processing index 9025
# Processing index 9026
# Processing index 9027
# Processing index 9028
# Processing index 9029
# Processing index 9030
# Processing index 9031
# Processing index 9032
# Processing index 9033
# Processing index 9034
# Processing index 9035
# Processing index 9036
# Processing index 9037
# Processing index 9038
# Processing index 9039
# Processing index 9040
# Processing index 9041
# Processing index 9042
# Processing index 9043
# Processing index 9044
# Processing index 9045
# Processing index 9046
# Processing index 9047
# Processing index 9048
# Processing index 9049
# Processing index 9050
# Processing index 9051
# Processing index 9052
# Processing index 9053
# Processing index 9054
# Processing index 9055
# Processing index 9056
# Processing index 9057
# Processing index 9058
# Processing index 9059
# Processing index 9060
# Processing index 9061
# Processing index 9062
# Processing index 9063
# Processing index 9064
# Processing index 9065
# Processing index 9066
# Processing index 9067
# Processing index 9068
# Processing index 9069
# Processing index 9070
# Processing index 9071
# Processing index 9072
# Processing index 9073
# Processing index 9074
# Processing index 9075
# Processing index 9076
# Processing index 9077
# Processing index 9078
# Processing index 9079
# Processing index 9080
# Processing index 9081
# Processing index 9082
# Processing index 9083
# Processing index 9084
# Processing index 9085
# Processing index 9086
# Processing index 9087
# Processing index 9088
# Processing index 9089
# Processing index 9090
# Processing index 9091
# Processing index 9092
# Processing index 9093
# Processing index 9094
# Processing index 9095
# Processing index 9096
# Processing index 9097
# Processing index 9098
# Processing index 9099
# Processing index 9100
# Processing index 9101
# Processing index 9102
# Processing index 9103
# Processing index 9104
# Processing index 9105
# Processing index 9106
# Processing index 9107
# Processing index 9108
# Processing index 9109
# Processing index 9110
# Processing index 9111
# Processing index 9112
# Processing index 9113
# Processing index 9114
# Processing index 9115
# Processing index 9116
# Processing index 9117
# Processing index 9118
# Processing index 9119
# Processing index 9120
# Processing index 9121
# Processing index 9122
# Processing index 9123
# Processing index 9124
# Processing index 9125
# Processing index 9126
# Processing index 9127
# Processing index 9128
# Processing index 9129
# Processing index 9130
# Processing index 9131
# Processing index 9132
# Processing index 9133
# Processing index 9134
# Processing index 9135
# Processing index 9136
# Processing index 9137
# Processing index 9138
# Processing index 9139
# Processing index 9140
# Processing index 9141
# Processing index 9142
# Processing index 9143
# Processing index 9144
# Processing index 9145
# Processing index 9146
# Processing index 9147
# Processing index 9148
# Processing index 9149
# Processing index 9150
# Processing index 9151
# Processing index 9152
# ...
# Processing index 11279
# Processing index 11280
# Processing index 11281
# Processing index 11282
# Processing index 11283
# Processing index 11284
# Processing index 11285
# Processing index 11286
# Processing index 11287
# Processing index 11288
# Processing index 11289
# Processing index 11290
# Processing index 11291
# Processing index 11292
# Processing index 11293
# Processing index 11294
# Processing index 11295
# Processing index 11296
# Processing index 11297
# Processing index 11298
# Processing index 11299
# Processing index 11300
# Processing index 11301
# Processing index 11302
# Processing index 11303
# Processing index 11304
# Processing index 11305
# Processing index 11306
# Processing index 11307
# Processing index 11308
# Processing index 11309
# Processing index 11310
# Processing index 11311
# Processing index 11312
# Processing index 11313
# Processing index 11314
# Processing index 11315
# Processing index 11316
# Processing index 11317
# Processing index 11318
# Processing index 11319
# Processing index 11320
# Processing index 11321
# Processing index 11322
# Processing index 11323
# Processing index 11324
# Processing index 11325
# Processing index 11326
# Processing index 11327
# Processing index 11328
# Processing index 11329
# Processing index 11330
# Processing index 11331
# Processing index 11332
# Processing index 11333
# Processing index 11334
# Processing index 11335
# Processing index 11336
# Processing index 11337
# Processing index 11338
# Processing index 11339
# Processing index 11340
# Processing index 11341
# Processing index 11342
# Processing index 11343
# Processing index 11344
# Processing index 11345
# Processing index 11346
# Processing index 11347
# Processing index 11348
# Processing index 11349
# Processing index 11350
# Processing index 11351
# Processing index 11352
# Processing index 11353
# Processing index 11354
# Processing index 11355
# Processing index 11356
# Processing index 11357
# Processing index 11358
# Processing index 11359
# Processing index 11360
# Processing index 11361
# Processing index 11362
# Processing index 11363
# Processing index 11364
# Processing index 11365
# Processing index 11366
# Processing index 11367
# Processing index 11368
# Processing index 11369
# Processing index 11370
# Processing index 11371
# Processing index 11372
# Processing index 11373
# Processing index 11374
# Processing index 11375
# Processing index 11376
# Processing index 11377
# Processing index 11378
# Processing index 11379
# Processing index 11380
# Processing index 11381
# Processing index 11382
# Processing index 11383
# Processing index 11384
# Processing index 11385
# Processing index 11386
# Processing index 11387
# Processing index 11388
# Processing index 11389
# Processing index 11390
# Processing index 11391
# Processing index 11392
# Processing index 11393
# Processing index 11394
# Processing index 11395
# Processing index 11396
# Processing index 11397
# Processing index 11398
# Processing index 11399
# Processing index 11400
# Processing index 11401
# Processing index 11402
# Processing index 11403
# Processing index 11404
# Processing index 11405
# Processing index 11406
# Processing index 11407
# Processing index 11408
# Processing index 11409
# Processing index 11410
# Processing index 11411
# Processing index 11412
# Processing index 11413
# Processing index 11414
# Processing index 11415
# Processing index 11416
# Processing index 11417
# Processing index 11418
# Processing index 11419
# Processing index 11420
# Processing index 11421
# Processing index 11422
# Processing index 11423
# Processing index 11424
# Processing index 11425
# Processing index 11426
# Processing index 11427
# Processing index 11428
# Processing index 11429
# Processing index 11430
# Processing index 11431
# Processing index 11432
# Processing index 11433
# Processing index 11434
# Processing index 11435
# Processing index 11436
# Processing index 11437
# Processing index 11438
# Processing index 11439
# Processing index 11440
# Processing index 11441
# Processing index 11442
# Processing index 11443
# Processing index 11444
# Processing index 11445
# Processing index 11446
# Processing index 11447
# Processing index 11448
# Processing index 11449
# Processing index 11450
# Processing index 11451
# Processing index 11452
# Processing index 11453
# Processing index 11454
# Processing index 11455
# Processing index 11456
# Processing index 11457
# Processing index 11458
# Processing index 11459
# Processing index 11460
# Processing index 11461
# Processing index 11462
# Processing index 11463
# Processing index 11464
# Processing index 11465
# Processing index 11466
# Processing index 11467
# Processing index 11468
# Processing index 11469
# Processing index 11470
# Processing index 11471
# Processing index 11472
# Processing index 11473
# Processing index 11474
# Processing index 11475
# Processing index 11476
# Processing index 11477
# Processing index 11478
# Processing index 11479
# Processing index 11480
# Processing index 11481
# Processing index 11482
# Processing index 11483
# Processing index 11484
# Processing index 11485
# Processing index 11486
# Processing index 11487
# Processing index 11488
# Processing index 11489
# Processing index 11490
# Processing index 11491
# Processing index 11492
# Processing index 11493
# Processing index 11494
# Processing index 11495
# Processing index 11496
# Processing index 11497
# Processing index 11498
# Processing index 11499
# Processing index 11500
# Processing index 11501
# Processing index 11502
# Processing index 11503
# Processing index 11504
# Processing index 11505
# Processing index 11506
# Processing index 11507
# Processing index 11508
# Processing index 11509
# Processing index 11510
# Processing index 11511
# Processing index 11512
# Processing index 11513
# Processing index 11514
# Processing index 11515
# Processing index 11516
# Processing index 11517
# Processing index 11518
# Processing index 11519
# Processing index 11520
# Processing index 11521
# Processing index 11522
# Processing index 11523
# Processing index 11524
# Processing index 11525
# Processing index 11526
# Processing index 11527
# Processing index 11528
# Processing index 11529
# Processing index 11530
# Processing index 11531
# Processing index 11532
# Processing index 11533
# Processing index 11534
# Processing index 11535
# Processing index 11536
# Processing index 11537
# Processing index 11538
# Processing index 11539
# Processing index 11540
# Processing index 11541
# Processing index 11542
# Processing index 11543
# Processing index 11544
# Processing index 11545
# Processing index 11546
# Processing index 11547
# Processing index 11548
# Processing index 11549
# Processing index 11550
# Processing index 11551
# Processing index 11552
# Processing index 11553
# Processing index 11554
# Processing index 11555
# Processing index 11556
# Processing index 11557
# Processing index 11558
# Processing index 11559
# Processing index 11560
# Processing index 11561
# Processing index 11562
# Processing index 11563
# Processing index 11564
# Processing index 11565
# Processing index 11566
# Processing index 11567
# Processing index 11568
# Processing index 11569
# Processing index 11570
# Processing index 11571
# Processing index 11572
# Processing index 11573
# Processing index 11574
# Processing index 11575
# Processing index 11576
# Processing index 11577
# Processing index 11578
# Processing index 11579
# Processing index 11580
# Processing index 11581
# Processing index 11582
# Processing index 11583
# Processing index 11584
# Processing index 11585
# Processing index 11586
# Processing index 11587
# Processing index 11588
# Processing index 11589
# Processing index 11590
# Processing index 11591
# Processing index 11592
# Processing index 11593
# Processing index 11594
# Processing index 11595
# Processing index 11596
# Processing index 11597
# Processing index 11598
# Processing index 11599
# Processing index 11600
# Processing index 11601
# Processing index 11602
# Processing index 11603
# Processing index 11604
# Processing index 11605
# Processing index 11606
# Processing index 11607
# Processing index 11608
# Processing index 11609
# Processing index 11610
# Processing index 11611
# Processing index 11612
# Processing index 11613
# Processing index 11614
# Processing index 11615
# Processing index 11616
# Processing index 11617
# Processing index 11618
# Processing index 11619
# Processing index 11620
# Processing index 11621
# Processing index 11622
# Processing index 11623
# Processing index 11624
# Processing index 11625
# Processing index 11626
# Processing index 11627
# Processing index 11628
# Processing index 11629
# Processing index 11630
# Processing index 11631
# Processing index 11632
# Processing index 11633
# Processing index 11634
# Processing index 11635
# Processing index 11636
# Processing index 11637
# Processing index 11638
# Processing index 11639
# Processing index 11640
# Processing index 11641
# Processing index 11642
# Processing index 11643
# Processing index 11644
# Processing index 11645
# Processing index 11646
# Processing index 11647
# Processing index 11648
# Processing index 11649
# Processing index 11650
# Processing index 11651
# Processing index 11652
# Processing index 11653
# Processing index 11654
# Processing index 11655
# Processing index 11656
# Processing index 11657
# Processing index 11658
# Processing index 11659
# Processing index 11660
# Processing index 11661
# Processing index 11662
# Processing index 11663
# Processing index 11664
# Processing index 11665
# Processing index 11666
# Processing index 11667
# Processing index 11668
# Processing index 11669
# Processing index 11670
# Processing index 11671
# Processing index 11672
# Processing index 11673
# Processing index 11674
# Processing index 11675
# Processing index 11676
# Processing index 11677
# Processing index 11678
# Processing index 11679
# Processing index 11680
# Processing index 11681
# Processing index 11682
# Processing index 11683
# Processing index 11684
# Processing index 11685
# Processing index 11686
# Processing index 11687
# Processing index 11688
# Processing index 11689
# Processing index 11690
# Processing index 11691
# Processing index 11692
# Processing index 11693
# Processing index 11694
# Processing index 11695
# Processing index 11696
# Processing index 11697
# Processing index 11698
# Processing index 11699
# Processing index 11700
# Processing index 11701
# Processing index 11702
# Processing index 11703
# Processing index 11704
# Processing index 11705
# Processing index 11706
# Processing index 11707
# Processing index 11708
# Processing index 11709
# Processing index 11710
# Processing index 11711
# Processing index 11712
# Processing index 11713
# Processing index 11714
# Processing index 11715
# Processing index 11716
# Processing index 11717
# Processing index 11718
# Processing index 11719
# Processing index 11720
# Processing index 11721
# Processing index 11722
# Processing index 11723
# Processing index 11724
# Processing index 11725
# Processing index 11726
# Processing index 11727
# Processing index 11728
# Processing index 11729
# Processing index 11730
# Processing index 11731
# Processing index 11732
# Processing index 11733
# Processing index 11734
# Processing index 11735
# Processing index 11736
# Processing index 11737
# Processing index 11738
# Processing index 11739
# Processing index 11740
# Processing index 11741
# Processing index 11742
# Processing index 11743
# Processing index 11744
# Processing index 11745
# Processing index 11746
# Processing index 11747
# Processing index 11748
# Processing index 11749
# Processing index 11750
# Processing index 11751
# Processing index 11752
# Processing index 11753
# Processing index 11754
# Processing index 11755
# Processing index 11756
# Processing index 11757
# Processing index 11758
# Processing index 11759
# Processing index 11760
# Processing index 11761
# Processing index 11762
# Processing index 11763
# Processing index 11764
# Processing index 11765
# Processing index 11766
# Processing index 11767
# Processing index 11768
# Processing index 11769
# Processing index 11770
# Processing index 11771
# Processing index 11772
# Processing index 11773
# Processing index 11774
# Processing index 11775
# Processing index 11776
# Processing index 11777
# Processing index 11778
# Processing index 11779
# Processing index 11780
# Processing index 11781
# Processing index 11782
# Processing index 11783
# Processing index 11784
# Processing index 11785
# Processing index 11786
# Processing index 11787
# Processing index 11788
# Processing index 11789
# Processing index 11790
# Processing index 11791
# Processing index 11792
# Processing index 11793
# Processing index 11794
# Processing index 11795
# Processing index 11796
# Processing index 11797
# Processing index 11798
# Processing index 11799
# Processing index 11800
# Processing index 11801
# Processing index 11802
# Processing index 11803
# Processing index 11804
# Processing index 11805
# Processing index 11806
# Processing index 11807
# Processing index 11808
# Processing index 11809
# Processing index 11810
# Processing index 11811
# Processing index 11812
# Processing index 11813
# Processing index 11814
# Processing index 11815
# Processing index 11816
# Processing index 11817
# Processing index 11818
# Processing index 11819
# Processing index 11820
# Processing index 11821
# Processing index 11822
# Processing index 11823
# Processing index 11824
# Processing index 11825
# Processing index 11826
# Processing index 11827
# Processing index 11828
# Processing index 11829
# Processing index 11830
# Processing index 11831
# Processing index 11832
# Processing index 11833
# Processing index 11834
# Processing index 11835
# Processing index 11836
# Processing index 11837
# Processing index 11838
# Processing index 11839
# Processing index 11840
# Processing index 11841
# Processing index 11842
# Processing index 11843
# Processing index 11844
# Processing index 11845
# Processing index 11846
# Processing index 11847
# Processing index 11848
# Processing index 11849
# Processing index 11850
# Processing index 11851
# Processing index 11852
# Processing index 11853
# Processing index 11854
# Processing index 11855
# Processing index 11856
# Processing index 11857
# Processing index 11858
# Processing index 11859
# Processing index 11860
# Processing index 11861
# Processing index 11862
# Processing index 11863
# Processing index 11864
# Processing index 11865
# Processing index 11866
# Processing index 11867
# Processing index 11868
# Processing index 11869
# Processing index 11870
# Processing index 11871
# Processing index 11872
# Processing index 11873
# Processing index 11874
# Processing index 11875
# Processing index 11876
# Processing index 11877
# Processing index 11878
# Processing index 11879
# Processing index 11880
# Processing index 11881
# Processing index 11882
# Processing index 11883
# Processing index 11884
# Processing index 11885
# Processing index 11886
# Processing index 11887
# Processing index 11888
# Processing index 11889
# Processing index 11890
# Processing index 11891
# Processing index 11892
# Processing index 11893
# Processing index 11894
# Processing index 11895
# Processing index 11896
# Processing index 11897
# Processing index 11898
# Processing index 11899
# Processing index 11900
# Processing index 11901
# Processing index 11902
# Processing index 11903
# Processing index 11904
# Processing index 11905
# Processing index 11906
# Processing index 11907
# Processing index 11908
# Processing index 11909
# Processing index 11910
# Processing index 11911
# Processing index 11912
# Processing index 11913
# Processing index 11914
# Processing index 11915
# Processing index 11916
# Processing index 11917
# Processing index 11918
# Processing index 11919
# Processing index 11920
# Processing index 11921
# Processing index 11922
# Processing index 11923
# Processing index 11924
# Processing index 11925
# Processing index 11926
# Processing index 11927
# Processing index 11928
# Processing index 11929
# Processing index 11930
# Processing index 11931
# Processing index 11932
# Processing index 11933
# Processing index 11934
# Processing index 11935
# Processing index 11936
# Processing index 11937
# Processing index 11938
# Processing index 11939
# Processing index 11940
# Processing index 11941
# Processing index 11942
# Processing index 11943
# Processing index 11944
# Processing index 11945
# Processing index 11946
# Processing index 11947
# Processing index 11948
# Processing index 11949
# Processing index 11950
# Processing index 11951
# Processing index 11952
# Processing index 11953
# Processing index 11954
# Processing index 11955
# Processing index 11956
# Processing index 11957
# Processing index 11958
# Processing index 11959
# Processing index 11960
# Processing index 11961
# Processing index 11962
# Processing index 11963
# Processing index 11964
# Processing index 11965
# Processing index 11966
# Processing index 11967
# Processing index 11968
# Processing index 11969
# Processing index 11970
# Processing index 11971
# Processing index 11972
# Processing index 11973

# %%
reviews_df
# Out:
#                 listing_id       date  reviewer_id  \
# 0                  1992333 2023-12-01     37012494
# 1                  1992333 2023-12-09     76872138
# 2                     3191 2023-12-23      9927643
# 3                    15007 2023-12-03    243886263
# 4                   897063 2023-12-01    398675800
# ...                    ...        ...          ...
# 11969  1045539636083237263 2023-12-27      8112629
# 11970  1045595447074880765 2023-12-17    313105614
# 11971  1048683134427485052 2023-12-19     41455737
# 11972  1049033266515220845 2023-12-25     26831109
# 11973  1045601601027572370 2023-12-22      1032934
#
#                                                 comments  \
# 0      What a place to stay! The view is breathtaking...
# 1      Search no further, this is the place to stay. ...
# 2      This was my second visit and it was as good as...
# 3      Thank you Dirk and your wife for wonderful wee...
# 4          Great place, great location and a great host.
# ...                                                  ...
# 11969  We were extremely comfortable during this visi...
# 11970  The apartment is brand new and definitely felt...
# 11971  I had an amazing stay in this very stylish apa...
# 11972  Anna's Camps Bay Retreat: ⭐⭐⭐⭐⭐<br/>Annas's ap...
# 11973  I will be back! <br/>What a beautiful apartmen...
#
#                                      translated_comments sentiment
# 0      What a place to stay! The view is breathtaking...      good
# 1      Search no further, this is the place to stay. ...      good
# 2      This was my second visit and it was as good as...      good
# 3      Thank you Dirk and your wife for wonderful wee...      good
# 4          Great place, great location and a great host.      good
# ...                                                  ...       ...
# 11969  We were extremely comfortable during this visi...      good
# 11970  The apartment is brand new and definitely felt...      good
# 11971  I had an amazing stay in this very stylish apa...      good
# 11972  Anna's Camps Bay Retreat: ⭐⭐⭐⭐⭐<br/>Annas's ap...      good
# 11973  I will be back! <br/>What a beautiful apartmen...      good
#
# [11974 rows x 6 columns]

# %% [markdown]
# Export to CSV

# %%
reviews_df.to_csv('Reviews.csv')
